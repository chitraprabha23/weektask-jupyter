# %%
#chitra prabha E

# %%
import numpy as np

# %%
chittu=np.array([88,99,77,66,55])
print("values:")
print(chittu)
# Out:
# values:
# [88 99 77 66 55]

# %%
print(chittu.shape)
# Out:
# (5,)

# %%
import pandas as pd

# %%
chithu=pd.Series([23,45,65,67])

# %%
print(chithu)
# Out:
# 0    23
# 1    45
# 2    65
# 3    67
# dtype: int64

# %%
data = {
    "name":["mithu","dhiya","sasti","vinthu","nethra"],
    "age":[21,22,23,24,25],
    "marks":[89,67,78,79,70]
}
df=pd.DataFrame(data)

# %%
print("DataFrame:")
print(df)
# Out:
# DataFrame:
#      name  age  marks
# 0   mithu   21     89
# 1   dhiya   22     67
# 2   sasti   23     78
# 3  vinthu   24     79
# 4  nethra   25     70

# %%
cd_df=pd.read_csv("C:/Users/chitr/Downloads/archive/train_and_test2.csv")

# %%
print(cd_df.head)
# Out:
# <bound method NDFrame.head of       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
print(cd_df.tail)
# Out:
# <bound method NDFrame.tail of       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
print(cd_df.size)
# Out:
# 36652

# %%
print(cd_df.shape)
# Out:
# (1309, 28)

# %%
print(cd_df.columns)
# Out:
# Index(['Passengerid', 'Age', 'Fare', 'Sex', 'sibsp', 'zero', 'zero.1',
#        'zero.2', 'zero.3', 'zero.4', 'zero.5', 'zero.6', 'Parch', 'zero.7',
#        'zero.8', 'zero.9', 'zero.10', 'zero.11', 'zero.12', 'zero.13',
#        'zero.14', 'Pclass', 'zero.15', 'zero.16', 'Embarked', 'zero.17',
#        'zero.18', '2urvived'],
#       dtype='str')
